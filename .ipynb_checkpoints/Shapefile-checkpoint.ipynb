# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# https://automating-gis-processes.github.io/2016/Lesson2-geopandas-basics.html

# %%
fp = "Data/Neighborhoods/Real_Property_Tax_Assessment_Neighborhoods.shp"

# %%
data = gpd.read_file(fp)

# %%
data
# Out:
#     OBJECTID      GIS_ID  NBHD  NBHD_NUM NBHD_TEXT NEIGHBORHO DESCRIPTIO  \
# 0          1   nhood_001   001         1         1
# 1          2   nhood_002   002         2         2
# 2          3   nhood_003   003         3         3
# 3          4   nhood_004   004         4         4
# 4          5   nhood_005   005         5         5
# 5          6   nhood_006   006         6         6
# 6          7   nhood_007   007         7         7
# 7          8   nhood_008   008         8         8
# 8          9   nhood_009   009         9         9
# 9         10  nhood_010a  010a        10       10a
# 10        11  nhood_010b  010b        10       10b
# 11        12   nhood_011   011        11        11
# 12        13   nhood_012   012        12        12
# 13        14   nhood_013   013        13        13
# 14        15   nhood_014   014        14        14
# 15        16   nhood_015   015        15        15
# 16        18   nhood_017   017        17        17
# ...

# %%
data['colors']=np.random.randint(0,5, size=len(data))
data['colors'].head()
# Out:
# 0    1
# 1    4
# 2    2
# 3    3
# 4    3
# Name: colors, dtype: int64

# %%
mymap=data.plot(figsize=(8,8))
mymap

# %%
data.plot(column='colors', cmap='Reds', alpha=1, categorical=False, legend=True, ax=None, figsize=(12,12));

# %%
shape=data[data['NBHD']=='003']
shape.plot(figsize=(5,5));

# %%
('data/Clusters/Neighborhood_Clusters.csv')

# %%
fp = "data/Clusters/Neighborhood_Clusters.shp"

# %%
clusters = gpd.read_file(fp)

# %%
clusters.plot(figsize=(12,12));
